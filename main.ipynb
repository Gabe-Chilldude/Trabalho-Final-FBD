# %% [markdown]
# # Trabalho Final de Fundamentos de Banco de Dados
#
# ## Equipe
#
# - Anna Liz Veríssimo Mendes
# - Gabriel Fernandes de Sousa
# - Kauan Ferreira da Silva
#
# # Bibliotecas usadas no projeto

# %%
import os
from dotenv import load_dotenv

import pandas as pd
import psycopg2 as pg
import sqlalchemy as sq
from sqlalchemy import create_engine
import panel as pn

# %% [markdown]
# # Conexão com banco de dados
#
# ## Carregar dados do .env

# %%
load_dotenv()
# Out:
# True

# %%
DB_HOST = os.getenv('DB_HOST')
DB_NAME = os.getenv('DB_NAME')
DB_USER = os.getenv('DB_USER')
DB_PASS = os.getenv('DB_PASS')

# %% [markdown]
# ## Conectar-se com banco de dados

# %%
con = pg.connect(host=DB_HOST, dbname=DB_NAME, user=DB_USER, password=DB_PASS)

# %%
cnx = f'postgresql://{DB_USER}:{DB_PASS}@{DB_HOST}/{DB_NAME}'

create_engine(cnx)
# Out:
# Engine(postgresql://postgres:***@localhost/dragao)

# %%
query = 'select * from dragoes'

pd.read_sql_query(query, cnx)
# Out:
#    id       nome               cor tamanho  id_personagem
# 0   1      Syrax           Amarelo  Grande            1.0
# 1   2    Caraxes          Vermelho  Grande            2.0
# 2   3     Vhagar  Bronze com Verde  Enorme            NaN
# 3   4    Sunfyre           Dourado  Grande            5.0
# 4   5  Dreamfyre             Prata  Grande            6.0
# 5   6   Balerion             Negro  Enorme            NaN
# 6   7     Meleys          Vermelho  Grande            4.0
# 7   8  Vermithor           Dourado  Grande            NaN

# %% [markdown]
# # Criando Interface

# %%
pn.extension()
pn.extension('tabulator')
pn.extension(notifications=True)
